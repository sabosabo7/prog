# %% [markdown]
# ## 線形回帰
# - 実際のデータを使って線形回帰を行う

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### 1. データの読み込み

# %%
df_diamond = pd.read_csv("../1_data/diamond_data.csv")

#ダイヤモンドの重さの単位であるカラットとその価格に関する実際のデータ。『回帰分析入門』より引用
display(df_diamond.head())
df_diamond.describe()
# Out:
#    carat  price
# 0   0.30   1302
# 1   0.30   1510
# 2   0.30   1510
# 3   0.30   1260
# 4   0.31   1641
#             carat         price
# count  308.000000    308.000000
# mean     0.630909   5019.483766
# std      0.277183   3403.115715
# min      0.180000    638.000000
# 25%      0.350000   1625.000000
# 50%      0.620000   4215.000000
# 75%      0.850000   7446.000000
# max      1.100000  16008.000000

# %%
x = df_diamond["carat"].values
y = df_diamond["price"].values

plt.scatter(x, y, marker='o')
plt.grid(which='major',color='black',linestyle=':')
plt.grid(which='minor',color='black',linestyle=':')
plt.ylabel('price')
plt.xlabel('carat')
plt.show()

# %% [markdown]
# ### 2. [演習] Scikit-learnを用いて線形回帰を実装してみましょう
# - w0, w1, 二乗誤差を表示し，回帰直線（モデルからの出力）をグラフに重ねて表示してみましょう

# %%
X=x.reshape(-1,1)

# %%
regr=LinearRegression(fit_intercept=True)
regr.fit(X,y)

y_est = regr.intercept_ + regr.coef_[0]*x
mse = 0.5* np.sum((y_est-y)**2)
print("w0={:2f},w1={:2f},mse={:2f}".format(regr.intercept_,regr.coef_[0],mse))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cee261a8ff62> in <module>
# ----> 1 regr=LinearRegression(fit_intercept=True)
#       2 regr.fit(X,y)
#       3
#       4 y_est = regr.intercept_ + regr.coef_[0]*x
#       5 mse = 0.5* np.sum((y_est-y)**2)
#
# NameError: name 'LinearRegression' is not defined

# %%
plt.scatter(x, y, marker='o')
plt.plot(x,y_est,color="red")
plt.grid(which='major',color='black',linestyle=':')
plt.grid(which='minor',color='black',linestyle=':')
plt.ylabel('price')
plt.xlabel('carat')
plt.show()
