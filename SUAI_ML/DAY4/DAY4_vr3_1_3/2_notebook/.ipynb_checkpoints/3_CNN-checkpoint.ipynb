# %% [markdown]
# ## 学習済みモデルを使って画像を識別する
#
# 使用する学習済みモデル:Inception-v3
# https://arxiv.org/pdf/1512.00567.pdf
#
# 学習済みモデルの利用方法：
# https://github.com/tensorflow/models/blob/v1.13.0/tutorials/image/imagenet/classify_image.py
#
# 1000クラスの内訳
# https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a

# %%
from PIL import Image

# %%
# 画像の確認
img = Image.open("../1_data/bridge.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x10FA19F60>

# %% [markdown]
# ### 識別の実行

# %%
# !python classify_image.py --image_file "../1_data/bridge.jpg"
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1115 23:03:11.544546 4683957696 deprecation_wrapper.py:119] From classify_image.py:227: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# >> Downloading inception-2015-12-05.tgz 100.0%
# Successfully downloaded inception-2015-12-05.tgz 88931400 bytes.
# W1115 23:03:22.594676 4683957696 deprecation_wrapper.py:119] From classify_image.py:139: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W1115 23:03:22.595897 4683957696 deprecation.py:323] From classify_image.py:141: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# W1115 23:03:22.598595 4683957696 deprecation_wrapper.py:119] From classify_image.py:125: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# 2019-11-15 23:03:23.985585: W tensorflow/core/framework/op_def_util.cc:357] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# W1115 23:03:24.896307 4683957696 deprecation_wrapper.py:119] From classify_image.py:146: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-15 23:03:24.901480: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# W1115 23:03:39.425572 4683957696 deprecation_wrapper.py:119] From classify_image.py:85: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# pier (score = 0.58902)
# suspension bridge (score = 0.25852)
# fireboat (score = 0.01189)
# promontory, headland, head, foreland (score = 0.00849)
# container ship, containership, container vessel (score = 0.00649)

# %%
# 画像の確認
img = Image.open("../1_data/park.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x250 at 0x10D12A278>

# %% [markdown]
# ### 識別の実行

# %%
# !python classify_image.py --image_file "../1_data/park.jpg"
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1115 23:03:47.381994 4583671232 deprecation_wrapper.py:119] From classify_image.py:227: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W1115 23:03:49.513573 4583671232 deprecation_wrapper.py:119] From classify_image.py:139: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W1115 23:03:49.513839 4583671232 deprecation.py:323] From classify_image.py:141: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# W1115 23:03:49.514531 4583671232 deprecation_wrapper.py:119] From classify_image.py:125: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# 2019-11-15 23:03:50.813755: W tensorflow/core/framework/op_def_util.cc:357] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# W1115 23:03:51.398088 4583671232 deprecation_wrapper.py:119] From classify_image.py:146: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-15 23:03:51.398916: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# W1115 23:04:02.406966 4583671232 deprecation_wrapper.py:119] From classify_image.py:85: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# seashore, coast, seacoast, sea-coast (score = 0.43565)
# promontory, headland, head, foreland (score = 0.19148)
# binoculars, field glasses, opera glasses (score = 0.03836)
# sleeping bag (score = 0.03438)
# mountain tent (score = 0.02826)

# %% [markdown]
# ### [問]
# * 上記の画像にて、人が認識されないのはなぜでしょうか？
#
# ### [演習]
# - 自分が持っている写真をいくつか読みこんで、識別させてみましょう。
# - 識別されやすい物体と識別されにくい物体を確認してみましょう。
