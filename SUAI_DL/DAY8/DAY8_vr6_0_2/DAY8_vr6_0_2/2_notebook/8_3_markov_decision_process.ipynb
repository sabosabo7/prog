# %% [markdown]
# # マルコフ決定過程の考え方を迷路問題を用いて確認する

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from common.meiro import State, Action, Environment

# %%
class Agent():
    """
    エージェントのクラス
    """
    def __init__(self, env):
        self.actions = env.actions

    def policy(self, state):
        """
        方策関数
        """
        # 仮のエージェントであるため、stateを使わずに
        # 次の行動を全くのランダムに選択する
        return np.random.choice(self.actions)

# %% [markdown]
# ## 実行

# %%
# 迷路の条件を設定する
grid = np.array([
                            [0, 0, 0, 1],
                            [0, 9, 0, -1],
                            [0, 0, 0, 0]
                        ])

# 環境をつくる
env = Environment(grid, move_prob=0.95, agent_init_state=(0,0))

# エージェントをつくる
agent = Agent(env)

# エピソード回数を設定する
num_episode = 100

# 迷路ゲームを実行する
li_total_rewards = []
for e in range(num_episode):

    # エージェントの初期位置を決める
    state = env.reset()
    
    # 報酬の合計を初期化する
    total_reward = 0
    
    # エピソード終了フラグを初期化
    done = False

    while not done:
        """
        1エピソードのループ
        """
        # 次の行動を選択する
        action = agent.policy(state)
        
        # その行動を実際にとってみてみると、次の状態と獲得報酬額がわかる
        next_state, reward, done = env.step(action)
        
        # 報酬を積算する
        total_reward += reward
        
        # 状態を更新する
        state = next_state

    print("Episode {}: Agent gets {} reward.".format(e, total_reward))
    li_total_rewards.append(total_reward)
# Out:
# Episode 0: Agent gets -2.08 reward.
# Episode 1: Agent gets -2.3600000000000003 reward.
# Episode 2: Agent gets -2.6800000000000006 reward.
# Episode 3: Agent gets -2.4000000000000004 reward.
# Episode 4: Agent gets -1.24 reward.
# Episode 5: Agent gets -2.8000000000000007 reward.
# Episode 6: Agent gets 0.6000000000000001 reward.
# Episode 7: Agent gets -3.7200000000000015 reward.
# Episode 8: Agent gets 0.92 reward.
# Episode 9: Agent gets -1.2 reward.
# Episode 10: Agent gets -1.8400000000000003 reward.
# Episode 11: Agent gets 0.56 reward.
# Episode 12: Agent gets 0.0399999999999997 reward.
# Episode 13: Agent gets -1.24 reward.
# Episode 14: Agent gets -1.0000000000000009 reward.
# Episode 15: Agent gets 0.1599999999999998 reward.
# Episode 16: Agent gets -0.48000000000000065 reward.
# Episode 17: Agent gets -2.0 reward.
# Episode 18: Agent gets -1.3599999999999999 reward.
# Episode 19: Agent gets -2.0 reward.
# Episode 20: Agent gets -2.7200000000000006 reward.
# Episode 21: Agent gets 0.76 reward.
# Episode 22: Agent gets -1.2 reward.
# Episode 23: Agent gets -2.4000000000000004 reward.
# Episode 24: Agent gets -2.16 reward.
# Episode 25: Agent gets 0.6000000000000001 reward.
# Episode 26: Agent gets -3.160000000000001 reward.
# Episode 27: Agent gets -0.16000000000000036 reward.
# Episode 28: Agent gets 0.4800000000000001 reward.
# Episode 29: Agent gets -1.6400000000000001 reward.
# Episode 30: Agent gets 0.52 reward.
# Episode 31: Agent gets -1.3200000000000012 reward.
# Episode 32: Agent gets 0.76 reward.
# Episode 33: Agent gets 0.44000000000000006 reward.
# Episode 34: Agent gets -2.24 reward.
# Episode 35: Agent gets -2.16 reward.
# Episode 36: Agent gets -3.7200000000000015 reward.
# Episode 37: Agent gets 0.19999999999999984 reward.
# Episode 38: Agent gets -3.9600000000000017 reward.
# Episode 39: Agent gets 0.56 reward.
# Episode 40: Agent gets -5.9600000000000035 reward.
# Episode 41: Agent gets -1.48 reward.
# Episode 42: Agent gets -1.8800000000000003 reward.
# Episode 43: Agent gets -1.6400000000000001 reward.
# Episode 44: Agent gets -1.48 reward.
# Episode 45: Agent gets -0.5200000000000007 reward.
# Episode 46: Agent gets 0.6799999999999999 reward.
# Episode 47: Agent gets -1.6800000000000002 reward.
# Episode 48: Agent gets -2.6400000000000006 reward.
# Episode 49: Agent gets 0.23999999999999988 reward.
# Episode 50: Agent gets -1.6400000000000001 reward.
# Episode 51: Agent gets -1.24 reward.
# Episode 52: Agent gets -1.28 reward.
# Episode 53: Agent gets -1.7600000000000002 reward.
# Episode 54: Agent gets 0.44000000000000006 reward.
# Episode 55: Agent gets 0.11999999999999977 reward.
# Episode 56: Agent gets -3.4800000000000013 reward.
# Episode 57: Agent gets 0.8 reward.
# Episode 58: Agent gets -1.6 reward.
# Episode 59: Agent gets -3.040000000000001 reward.
# Episode 60: Agent gets -1.24 reward.
# Episode 61: Agent gets -1.52 reward.
# Episode 62: Agent gets -2.8000000000000007 reward.
# Episode 63: Agent gets -0.5200000000000007 reward.
# Episode 64: Agent gets -1.7200000000000002 reward.
# Episode 65: Agent gets -1.32 reward.
# Episode 66: Agent gets -2.4800000000000004 reward.
# Episode 67: Agent gets -1.3599999999999999 reward.
# Episode 68: Agent gets 0.11999999999999977 reward.
# Episode 69: Agent gets -2.12 reward.
# Episode 70: Agent gets -2.3200000000000003 reward.
# Episode 71: Agent gets 0.8 reward.
# Episode 72: Agent gets -2.8000000000000025 reward.
# Episode 73: Agent gets -1.8800000000000003 reward.
# Episode 74: Agent gets -2.8000000000000007 reward.
# Episode 75: Agent gets 0.72 reward.
# Episode 76: Agent gets -1.6400000000000001 reward.
# Episode 77: Agent gets 0.72 reward.
# Episode 78: Agent gets -3.040000000000001 reward.
# Episode 79: Agent gets 0.4 reward.
# Episode 80: Agent gets -1.44 reward.
# Episode 81: Agent gets -2.2800000000000002 reward.
# Episode 82: Agent gets -1.44 reward.
# Episode 83: Agent gets 0.44000000000000006 reward.
# Episode 84: Agent gets -2.080000000000002 reward.
# Episode 85: Agent gets 0.72 reward.
# Episode 86: Agent gets -2.320000000000002 reward.
# Episode 87: Agent gets -2.220446049250313e-16 reward.
# Episode 88: Agent gets -1.8400000000000003 reward.
# Episode 89: Agent gets -1.6400000000000001 reward.
# Episode 90: Agent gets 0.56 reward.
# Episode 91: Agent gets 0.84 reward.
# Episode 92: Agent gets -3.4000000000000012 reward.
# Episode 93: Agent gets 0.4800000000000001 reward.
# Episode 94: Agent gets -3.4000000000000012 reward.
# Episode 95: Agent gets -0.24000000000000044 reward.
# Episode 96: Agent gets -1.7600000000000002 reward.
# Episode 97: Agent gets 0.31999999999999995 reward.
# Episode 98: Agent gets -4.720000000000002 reward.
# Episode 99: Agent gets -4.320000000000002 reward.

# %% [markdown]
# ## 結果の可視化

# %%
# グラフ
pd.DataFrame({"total_reward":li_total_rewards}).plot()
plt.ylabel("total reward")
plt.xlabel("episode")
plt.show()

# %% [markdown]
# ### [演習]
# * 上記のコードには、方策関数を学習させる仕組みが入っていないため、エピソードをなんど繰り返しても報酬合計は大きくなりません
# * 方策関数をかしこくするには、どのような考え方を導入すればいいでしょうか？
